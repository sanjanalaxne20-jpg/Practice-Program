# %%
#Check Binary Number
num = input("Enter a binary number: ")

if set(num) <= {"0", "1"}:
    print("Valid Binary")
else:
    print("Invalid Binary")
# Out:
# Enter a binary number:  4567801
# Invalid Binary

# %%
#Check Whether a Number is Buzz Number
num = int(input("Enter a number: "))

if num % 7 == 0 or str(num).endswith("7"):
    print("Buzz Number")
else:
    print("Not Buzz Number")
# Out:
# Enter a number:  24
# Not Buzz Number

# %%
#Find Product of Digits
num = input("Enter a number: ")

product = 1

for i in num:
    product *= int(i)

print("Product =", product)
# Out:
# Enter a number:  54
# Product = 20

# %%
#Check Whether a Character is a Vowel
ch = input("Enter a character: ")

if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  sea
# Consonant

# %%
#Check Whether a Character is a Vowel
ch = input("Enter a character: ")

if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  aei
# Vowel

# %%
#Count the Number of Lines
text = input("Enter text using / as line separator: ")

print("Lines =", len(text.split("/")))
# Out:
# Enter text using / as line separator:  python,java,c++
# Lines = 1

# %%
#Find the Largest Digit
num = input("Enter a number: ")

print("Largest Digit =", max(num))
# Out:
# Enter a number:  456890
# Largest Digit = 9

# %%
#Find the Largest Digit
num = input("Enter a number: ")

print("Smallest Digit =", min(num))
# Out:
# Enter a number:  3412
# Smallest Digit = 1

# %%
#Count Spaces in a String
text = input("Enter a sentence: ")

count = text.count(" ")

print("Spaces =", count)
# Out:
# Enter a sentence:  hii iam python
# Spaces = 2

# %%
#Check Automorphic Number
num = int(input("Enter a number: "))

square = num * num

if str(square).endswith(str(num)):
    print("Automorphic Number")
else:
    print("Not Automorphic Number")
# Out:
# Enter a number:  43
# Not Automorphic Number

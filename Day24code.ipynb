# %%
#Find Square Root of User Input
import math
num = int(input("Enter a number: "))
print("Square Root =", math.sqrt(num))
# Out:
# Enter a number:  3
# Square Root = 1.7320508075688772

# %%
#Find Factorial of User Input
import math
num = int(input("Enter a number: "))
print("Factorial =", math.factorial(num))
# Out:
# Enter a number:  4
# Factorial = 24

# %%
#Find x² + y²
import math
x = 5
y = 8
result = math.pow(x, 2) + math.pow(y, 2)
print(result)
# Out:
# 89.0

# %%
#Find x³ + y³
import math
x = 2
y = 3
result = math.pow(x, 3) + math.pow(y, 3)
print(result)
# Out:
# 35.0

# %%
#Find √(a²+b²)
import math
a = 6
b = 8
print(math.sqrt(a*a + b*b))
# Out:
# 10.0

# %%
#Find Area of Triangle (Heron's Formula)
import math
a = 3
b = 4
c = 5
s = (a+b+c)/2
area = math.sqrt(s*(s-a)*(s-b)*(s-c))
print(area)
# Out:
# 6.0

# %%
#Find Percentage
import math
obtained = 420
total = 500
percentage = (obtained/total)*100
print(percentage)
# Out:
# 84.0

# %%
#Find Average of Three Numbers
import math
a = 20
b = 30
c = 40
print((a+b+c)/3)
# Out:
# 30.0

# %%
#Find Absolute Sum
import math
a = -15
b = -25
print(math.fabs(a+b))
# Out:
# 40.0

# %%
#Find Quotient and Remainder
import math
a = 29
b = 4
print("Quotient =", a//b)
print("Remainder =", a%b)
# Out:
# Quotient = 7
# Remainder = 1

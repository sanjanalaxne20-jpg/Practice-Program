# %%
#Find Pi Value
import math

print(math.pi)
# Out:
# 3.141592653589793

# %%
#Find Euler's Number
import math
print(math.e)
# Out:
# 2.718281828459045

# %%
#Find Hypotenuse
import math
print(math.hypot(3, 4))
# Out:
# 5.0

# %%
#Convert Degrees to Radians
import math
print(math.radians(180))
# Out:
# 3.141592653589793

# %%
#Convert Radians to Degrees
import math
print(math.degrees(math.pi))
# Out:
# 180.0

# %%
#Two Numbers Sum
import math

a = 10
b = 20

result = a + b

print("Sum =", result)
# Out:
# Sum = 30

# %%
#two numbers substract
import math
a=30
b=20
result=a-b
print("sub = ",result)
# Out:
# sub =  10

# %%
#multiply two numbers
import math
a=30
b=19
result=a*b
print("Mul = ",result)
# Out:
# Mul =  570

# %%
#LCM
import math
a = 12
b = 18
print(math.lcm(a, b))
# Out:
# 36

# %%
#gcd
import math
a = 12
b = 18
print(math.gcd(a, b))
# Out:
# 6

# %%
#list function
l1=[2,5,7,8,9,3,4,55,6,7]
l1
# Out:
# [2, 5, 7, 8, 9, 3, 4, 55, 6, 7]

# %%
list(filter(lambda x: x>5,l1))
# Out:
# [7, 8, 9, 55, 6, 7]

# %%
#find the sum using the functools
import functools
functools.reduce(lambda sum,y : sum+y,l1)
# Out:
# 106

# %%
import functools
functools.reduce(lambda x,y : x+y,l1)
# Out:
# 106

# %%
#find out the highest value from the list
functools.reduce(lambda x,y : x if x>y else y,l1)
# Out:
# 55

# %%
#Smallest number
functools.reduce(lambda x,y : x if x<y else y,l1)
# Out:
# 2

# %%
import math

# %%
math.sqrt(25)#finding the square root using the math
# Out:
# 5.0

# %%
math.cbrt(8)#find the cube root using the math
# Out:
# 2.0

# %%
import math
print(math.gcd(36, 24))  # Greatest Common Divisor
# Out:
# 12

# %%
#finding the factorial using the math function
import math
print(math.factorial(5))
# Out:
# 120

# %%
#find the power using the math functions
import math
print(math.pow(3,2))
# Out:
# 9.0

# %%
#find the floor value
import math
print(math.floor(3.5))
# Out:
# 3

# %%
#Find Ceiling Value
import math
print(math.ceil(7.2))  # Rounds up
# Out:
# 8

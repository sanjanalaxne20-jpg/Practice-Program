# %%
s1={}
print(type(s1))
# Out:
# <class 'dict'>

# %%
s2=set()
print(type(s2))
# Out:
# <class 'set'>

# %%
s3={1,2,3,4,5}
s3
# Out:
# {1, 2, 3, 4, 5}

# %%
s4={1,"ram",78.86}
s4
# Out:
# {1, 78.86, 'ram'}

# %%
s3.add(20)
s3
# Out:
# {1, 2, 3, 4, 5, 20}

# %%
s3.update("a,b,c")
s3
# Out:
# {',', 1, 2, 20, 3, 4, 5, 'a', 'b', 'c'}

# %%
s3.add("pune")
s3
# Out:
# {',', 1, 2, 20, 3, 4, 5, 'a', 'b', 'c', 'pune'}

# %%
s3.remove("pune")
s3
# Out:
# {',', 1, 2, 20, 3, 4, 5, 'a', 'b', 'c'}

# %%
s3.remove(1)
s3
# Out:
# {',', 2, 20, 3, 4, 5, 'a', 'b', 'c'}

# %%
s3.discard(20)
s3
# Out:
# {',', 2, 3, 4, 5, 'a', 'b', 'c'}

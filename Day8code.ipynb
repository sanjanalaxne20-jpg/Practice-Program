# %%
#remove Duplicate elements
numbers=[1,2,2,3,4,4,5]
unique=list(set(numbers))
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Search element in a list
numbers=[10,20,30,40,50]
num=int(input("Enter number:"))
if num in numbers:
    print("Found")
else:
    print("Not Found")
# Out:
# Enter number: 30
# Found

# %%
#Search element in a list
numbers=[10,20,30,40,50]
num=int(input("Enter number:"))
if num in numbers:
    print("Found")
else:
    print("Not Found")
# Out:
# Enter number: 60
# Not Found

# %%
#Multiply all elements
numbers=[2,3,4]
product=1
for i in numbers:
    product=product*i
print("Product=",product)
# Out:
# Product= 24

# %%
#merge to list
l1=[1,2,3]
l2=[4,5,6]
l3=l1+l2
print(l3)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#check if a list is empty
numbers=[]
if len(numbers)==0:
    print("list is empty")
else:
    print("List is not empty")
# Out:
# list is empty

# %%
#print positive numbers
numbers=[10,3,-4,6,77,8]
for i in numbers:
    if i>0:
        print(i)
# Out:
# 10
# 3
# 6
# 77
# 8

# %%
#find the common numbers in two list
l1=[1,2,3,4]
l2=[2,4,5,4]
for i in l1:
    if i in l2:
        print(i)
# Out:
# 2
# 4

# %%
#find the index of the element
l1=[1,2,3,4,5,6]
print(l1.index(4))
# Out:
# 3

# %%
#insert number at given specific position
1=[10,20,30,40,50]
l1.insert(2,30)
print(l1)
# Out:
# [10, 20, 30, 30, 40, 50]
